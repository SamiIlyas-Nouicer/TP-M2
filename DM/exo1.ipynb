# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Specify the column names to ensure consistency
column_names = ['ep (ms)', 'Acc_x', 'Acc_y', 'Acc_z', 'Gyro_x', 'Gyro_y', 'Gyro_z', 'ID', 'Label', 'Category', 'Set']

# Read the CSV while specifying column names
df = pd.read_csv('data2.csv', names=column_names, skiprows=1,sep=',')

print(df.dtypes)
# Out:
# ep (ms)      object
# Acc_x       float64
# Acc_y       float64
# Acc_z       float64
# Gyro_x      float64
# Gyro_y      float64
# Gyro_z      float64
# ID           object
# Label        object
# Category     object
# Set         float64
# dtype: object

# %%
df
# Out:
#                                                 ep (ms) Acc_x  Acc_y  Acc_z  \
# 0     2019-01-11 15:08:05.200;0.0135;0.977;-0.071;-2...   NaN    NaN    NaN
# 1     2019-01-11 15:08:05.400;-0.0014999999999999996...   NaN    NaN    NaN
# 2     2019-01-11 15:08:05.600;0.0013333333333333333;...   NaN    NaN    NaN
# 3     2019-01-11 15:08:05.800;-0.024;0.957;-0.0735;8...   NaN    NaN    NaN
# 4     2019-01-11 15:08:06.000;-0.027999999999999997;...   NaN    NaN    NaN
# ...                                                 ...   ...    ...    ...
# 9004  2019-01-20 17:33:27.000;-0.048;-10.415;-0.0765...   NaN    NaN    NaN
# 9005  2019-01-20 17:33:27.200;-0.037;1.151.994.539;-...   NaN    NaN    NaN
# 9006  2019-01-20 17:33:27.400;-0.06;274.571.263;-0.0...   NaN    NaN    NaN
# 9007  2019-01-20 17:33:27.600;-0.03866666666666666;-...   NaN    NaN    NaN
# 9008  2019-01-20 17:33:27.800;-0.044;-1.034;-0.059;1...   NaN    NaN    NaN
#
#       Gyro_x  Gyro_y  Gyro_z  ID  Label  Category  Set
# 0        NaN     NaN     NaN NaN    NaN       NaN  NaN
# 1        NaN     NaN     NaN NaN    NaN       NaN  NaN
# 2        NaN     NaN     NaN NaN    NaN       NaN  NaN
# 3        NaN     NaN     NaN NaN    NaN       NaN  NaN
# 4        NaN     NaN     NaN NaN    NaN       NaN  NaN
# ...      ...     ...     ...  ..    ...       ...  ...
# 9004     NaN     NaN     NaN NaN    NaN       NaN  NaN
# 9005     NaN     NaN     NaN NaN    NaN       NaN  NaN
# 9006     NaN     NaN     NaN NaN    NaN       NaN  NaN
# 9007     NaN     NaN     NaN NaN    NaN       NaN  NaN
# 9008     NaN     NaN     NaN NaN    NaN       NaN  NaN
#
# [9009 rows x 11 columns]

# %%
# # Fill NaN with empty strings, strip whitespace, and convert to numeric
# for column in ['Acc_x', 'Acc_y', 'Acc_z', 'Gyro_x', 'Gyro_y', 'Gyro_z', 'Set']:
#     df[column] = df[column].fillna('').astype(str).str.strip()  # Strip whitespace
#     df[column] = pd.to_numeric(df[column], errors='coerce')     # Convert to numeric

# # Check the updated data types
# print(df.dtypes)print(df.dtypes)

# %%
def calculate_mean(data):
    return sum(data) / len(data)

def calculate_median(data):
    sorted_data = sorted(data)
    n = len(sorted_data)
    mid = n // 2
    
    if n % 2 == 0:
        return (sorted_data[mid - 1] + sorted_data[mid]) / 2
    else:
        return sorted_data[mid]

def calculate_mode(data):
    frequency = {}
    for value in data:
        frequency[value] = frequency.get(value, 0) + 1

    max_frequency = max(frequency.values())
    modes = [key for key, value in frequency.items() if value == max_frequency]
    
    return modes if len(modes) > 1 else modes[0] 

def calculate_central_tendencies(data):
    mean_value = calculate_mean(data)
    median_value = calculate_median(data)
    mode_value = calculate_mode(data)
    
    return {
        'Mean': mean_value,
        'Median': median_value,
        'Mode': mode_value
    }

# %%
column_data = df['Acc_z'].dropna().tolist() 
central_tendencies = calculate_central_tendencies(column_data)

print(central_tendencies)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 column_data = df['Acc_z'].dropna().tolist()
# ----> 2 central_tendencies = calculate_central_tendencies(column_data)
#       4 print(central_tendencies)
#
# Cell In[39], line 25, in calculate_central_tendencies(data)
#      24 def calculate_central_tendencies(data):
# ---> 25     mean_value = calculate_mean(data)
#      26     median_value = calculate_median(data)
#      27     mode_value = calculate_mode(data)
#
# Cell In[39], line 2, in calculate_mean(data)
#       1 def calculate_mean(data):
# ----> 2     return sum(data) / len(data)
#
# ZeroDivisionError: division by zero

# %%
mean_value = df['Acc_z'].mean()  # Example for the Acc_x column
median_value = df['Acc_z'].median()  # Example for the Acc_x column
mode_value = df['Acc_z'].mode()  # Example for the Acc_x column

print(mean_value)
print(median_value)
print(mode_value)
# Out:
# 0.10777982144180188
# -0.031
# 0   -0.125
# 1   -0.120
# 2   -0.095
# Name: Acc_z, dtype: float64

# %%
def calculate_quartiles(data):
    sorted_data = sorted(data)
    n = len(sorted_data)

    if n == 0:
        raise ValueError("The input data is empty.")

    q0 = sorted_data[0]
    q5 = sorted_data[-1]

    q1 = calculate_percentile(sorted_data, 0.2)
    q2 = calculate_percentile(sorted_data, 0.4)
    q3 = calculate_percentile(sorted_data, 0.6)
    q4 = calculate_percentile(sorted_data, 0.8)

    return {
        'Q0': q0,
        'Q1': q1,
        'Q2': q2,
        'Q3': q3,
        'Q4': q4,
        'Q5': q5
    }

def calculate_percentile(sorted_data, percentile):
    index = percentile * (len(sorted_data) - 1)
    if index.is_integer():
        return sorted_data[int(index)]
    else:
        lower_index = int(index)
        upper_index = lower_index + 1
        return (sorted_data[lower_index] + sorted_data[upper_index]) / 2

# %%
column_data = df['Acc_z'].dropna().tolist() 

quantiles = calculate_quartiles(column_data)

print(quantiles)
# Out:
# {'Q0': -0.6193333333333334, 'Q1': -0.149, 'Q2': -0.0708333333333333, 'Q3': 0.062, 'Q4': 0.423, 'Q5': 10.175}

# %%
import pandas as pd

def display_informations(df, column_name):

    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")
    
    total_values = df[column_name].shape[0]  
    missing_values = df[column_name].isnull().sum()  
    percentage_missing = (missing_values / total_values) * 100  
    unique_values = df[column_name].nunique()  
    unique_values_list = df[column_name].unique()  
    # Display results
    print(f"General informations  for '{column_name}':")
    print(f"Number of missing values: {missing_values}")
    print(f"Percentage of missing values: {percentage_missing:.2f}%")
    print(f"Number of unique values: {unique_values}")
    print(f"Unique values: {unique_values_list}")

# %%
display_informations(df, 'Acc_z')  # Replace 'Acc_x' with your desired column name
# Out:
# General informations  for 'Acc_z':
# Number of missing values: 11
# Percentage of missing values: 0.12%
# Number of unique values: 3280
# Unique values: [-0.071      -0.0795     -0.06433333 ...  0.2385      0.114
#   0.098     ]
