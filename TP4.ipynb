# %%
import numpy as np

# Calcul du gradient horizontal (déjà donné)
grad_x = img[:, :img.shape[1]-1] - img[:, 1:]

# Calcul du gradient vertical
grad_y = img[:img.shape[0]-1, :] - img[1:, :]

# Pour la magnitude, il faut aligner les dimensions de grad_x et grad_y
grad_x = grad_x[:grad_y.shape[0], :]  # Ajustement des dimensions si nécessaire
grad_y = grad_y[:, :grad_x.shape[1]]  # Ajustement des dimensions si nécessaire

# Magnitude du gradient
magnitude = np.sqrt(grad_x**2 + grad_y**2)
