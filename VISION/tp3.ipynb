# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randrange
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
voisinage = 3

def filtreMoyenNVG(img):
    h, w = img.shape
    imgMoy = np.zeros(img.shape, np.uint8)
    
    for y in range(h):
        for x in range(w):
            if x < voisinage / 2 or x > w - voisinage / 2 or y < voisinage / 2 or y > h - voisinage / 2:
                imgMoy[y, x] = img[y, x]
            else:
                m = int(voisinage/2)
                imgV = img[y-m:y+m+1,x-m:x+m+1]
               
                
                imgMoy[y, x] = np.mean(imgV)
    
    return imgMoy

def filtreMedianNVG(img):
    h, w = img.shape
    imgMoy = np.zeros(img.shape, np.uint8)
    
    for y in range(h):
        for x in range(w):
            if x < voisinage / 2 or x > w - voisinage / 2 or y < voisinage / 2 or y > h - voisinage / 2:
                imgMoy[y, x] = img[y, x]
            else:
                 m = int(voisinage/2)
                 imgV = img[y-m:y+m+1,x-m:x+m+1]
                
                 imgMoy[y, x] = np.median(imgV)
    
    return imgMoy

# %%
img = cv2.imread('pic.jpeg',cv2.IMREAD_GRAYSCALE)
imgMoy = filtreMoyenNVG(img)
imgMed = filtreMedianNVG(img)                                          
cv2.imshow('image source ', img)
cv2.imshow("image moy", imgMoy)
cv2.imshow('image med',imgMed)
cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/sami/Desktop/TP-M2/VISION/visionenv/lib/python3.12/site-packages/cv2/qt/plugins"
# 97
